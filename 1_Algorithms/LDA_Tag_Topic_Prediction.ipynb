# %% [markdown]
# # LDA Topic Prediction on Song Tags
#
# This notebook will take the tags belonging to our song dataset and turn them into vectors of topics using latent Dirichlet allocation (LDA). A deep dive on this topic is available at the Sagemaker documentation here: https://docs.aws.amazon.com/sagemaker/latest/dg/lda.html
#
# Credit is due to the AWS documentation for some blocks of code setting up the training and preparation of this data.
#
# Our first step, as always, will be to bring in the packages we will need.

# %%
import pandas as pd
import numpy as np
import os
import glob
import json
import itertools as it
import json
import datetime as dt
import string
import boto3
from decimal import Decimal

import sagemaker
from sagemaker.amazon.common import numpy_to_record_serializer
from sagemaker.predictor import csv_serializer, json_deserializer
from sagemaker import get_execution_role
import sagemaker.amazon.common as smac
import io

import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Data Preparation
#
# A lot of the data cleaning has taken place in the EC2 instance in which the data was retrieved. There is little left for us to do in this notebook but convert the cleaned tags into a machine readable format for training.
#
# Below, we instantiate a TFIDF vectorizer class that we will use to convert the tags into floating points.

# %%
#we're going to use a TFIDF to encode the tags for each song
#setting the minimum number of times a word occurs to 50 to get counted
tf = TfidfVectorizer(
    stop_words='english',
    sublinear_tf=True,
    strip_accents='unicode',
#     max_features= 25000
    min_df = 50
)

# %%
#pointing to the data we'll use for training
bucket='sagemaker-msdsubset'
data_key = 'flat_summary_04_09_20.csv'
prefix = 'sagemaker/preprocessed_lda'
role = get_execution_role()

data_location = 's3://{}/{}'.format(bucket, data_key)

flat = pd.read_csv(data_location, names = ['song_id', 'track_id', 'song_hotness', 'artist_familiarity',
       '7digital_id', 'title', 'artist', 'mode', 'tempo', 'key', 'artist_id',
       'spotify_uri_final', 'last_fm_tags'])

#the LDA can't predict on empty strings, so we have to drop those songs
flat = flat[~flat['last_fm_tags'].isnull()]

flat.head()
# Out:
#               song_id            track_id  song_hotness  artist_familiarity  \
# 0  SOQMMHC12AB0180CB8  TRMMMYQ128F932D901      0.542899            0.649822
# 1  SOVFVAK12A8C1350D9  TRMMMKD128F425225D      0.299877            0.439604
# 2  SOGTUKN12AB017F4F1  TRMMMRX128F93187D9      0.617871            0.643681
# 3  SOBNYVR12A8C13558C  TRMMMCH128F425532C      0.000000            0.448501
# 4  SOHSBXH12A8C13B0DF  TRMMMWA128F426B589      0.000000            0.000000
#
#    7digital_id              title            artist  mode    tempo  key  \
# 0      7032331       Silent Night  Faster Pussy cat     0   87.002   10
# 1      1514808        Tanssi vaan  Karkkiautomaatti     1  150.778    9
# 2      6945353  No One Could Ever    Hudson Mohawke     1  177.768    7
# 3      2168257      Si Vos Querés       Yerba Brava     1   87.433    7
# 4      2264873   Tangle Of Aspens        Der Mystic     0  140.035    5
#
#             artist_id                     spotify_uri_final  \
# 0  ARYZTJS1187B98C555                                   NaN
# 1  ARMVN3U1187FB3A1EB  spotify:track:6DOmOjeTc3btomrfFfPgy8
# 2  ARGEKB01187FB50750  spotify:track:41RpZW2lxAdnqDd2nMBzLQ
# 3  ARNWYLR1187B9B2F9C  spotify:track:7z4BZV7eZO1bqVKwAeTmou
# 4  AREQDTE1269FB37231  spotify:track:2poHURuOfVNbzZdivAwtOH
#
#                                         last_fm_tags
# 0  heavymetal,industrialmetal,hardrock,glammetal,...
# 1  poprock,indierock,chillout,rock,alternativeroc...
# 2  brokenbeat,hiphop,triphop,glitch,ghettotech,ro...
# 3  cumbia,italiandisco,losangeles,electronic,coun...
# 4  hardtrance,darkpop,trance,electronica,dub,elec...

# %%
#we're going to use TFIDF on the tags
##this was instantiated above
x_tf = tf.fit_transform(flat['last_fm_tags'])

#put them into a bytesIO object
#this is because TFIDF returns a sparse matrix
##and memory isnt sufficient for dense 
buf = io.BytesIO()
smac.write_spmatrix_to_sparse_tensor(file = buf, array = x_tf)
buf.seek(0)

#Sagemaker trains from data stored in an S3 bucket
#so let's upload to this S3 bucket
train_key = 'recordio-tfidf-data'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', train_key)).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, train_key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://sagemaker-msdsubset/sagemaker/preprocessed_lda/train/recordio-tfidf-data

# %% [markdown]
# # Training
#
# Below, we read in the most recent image of our training algorithm. We then set up the hyperparameters of the training instance and fit it on the S3 instance we uploaded above.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
# select the algorithm container based on this notebook's current location

region_name = boto3.Session().region_name
container = get_image_uri(region_name, 'lda')

# %%
session = sagemaker.Session()

# specify general training job information
lda = sagemaker.estimator.Estimator(
    container,
    role,   #environment variable set above
    output_path='s3://{}/{}/output'.format(bucket, prefix), #point to our data
    train_instance_count=1, #LDA only supports single CPU training
    train_instance_type='ml.c4.2xlarge',
    sagemaker_session=session,
)

# set algorithm-specific hyperparameters
lda.set_hyperparameters(
    num_topics=10, #selected due to sparsity of tags in dataset for each song
    feature_dim=len(tf.vocabulary_),
    mini_batch_size=x_tf.shape[0],
    alpha0=1.0,
)

# run the training job on input data stored in S3
lda.fit({'train': s3_train_data})
# Out:
# 2020-04-11 16:29:25 Starting - Starting the training job...
# 2020-04-11 16:29:26 Starting - Launching requested ML instances...
# 2020-04-11 16:30:21 Starting - Preparing the instances for training......
# 2020-04-11 16:31:24 Downloading - Downloading input data
# 2020-04-11 16:31:24 Training - Downloading the training image......
# 2020-04-11 16:32:11 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Using mxnet backend.
# [04/11/2020 16:32:13 INFO 139870123513664] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'alpha0': u'1.0', u'max_restarts': u'10', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'allow_svd_init': u'true', u'epochs': u'1', u'tol': u'1e-8', u'_kvstore': u'local', u'max_iterations': u'1000'}
# [04/11/2020 16:32:13 INFO 139870123513664] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'29287', u'mini_batch_size': u'1009315', u'num_topics': u'10', u'alpha0': u'1.0'}
# [04/11/2020 16:32:13 INFO 139870123513664] Final configuration: {u'alpha0': u'1.0', u'max_restarts': u'10', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'allow_svd_init': u'true', u'epochs': u'1', u'feature_dim': u'29287', u'num_topics': u'10', u'tol': u'1e-8', u'_kvstore': u'local', u'mini_batch_size': u'1009315', u'max_iterations': u'1000'}
# [04/11/2020 16:32:13 INFO 139870123513664] Using default worker.
# [04/11/2020 16:32:13 INFO 139870123513664] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [04/11/2020 16:32:17 INFO 139870123513664] Running LDA for 13 topics (10 requested)
# #metrics {"Metrics": {"LDA.initialize.time": {"count": 1, "max": 0.47206878662109375, "sum": 0.47206878662109375, "min": 0.47206878662109375}}, "EndTime": 1586622737.656986, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm":
"Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622767.263728}
#
# #metrics {"Metrics": {"GetMoments.time": {"count": 1, "max": 24216.499090194702, "sum": 24216.499090194702, "min": 24216.499090194702}}, "EndTime": 1586622767.268796, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622767.266326}
#
# /opt/amazon/lib/python2.7/site-packages/lda/cumulants.py:216: RuntimeWarning: Algorithm assumes alpha0 < 1.0. May return poor results
#   RuntimeWarning)
# #metrics {"Metrics": {"e3_term1.time": {"count": 1, "max": 1137.458086013794, "sum": 1137.458086013794, "min": 1137.458086013794}}, "EndTime": 1586622770.593868, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622767.268851}
#
# #metrics {"Metrics": {"e3_term2.time": {"count": 1, "max": 17.089128494262695, "sum": 17.089128494262695, "min": 17.089128494262695}}, "EndTime": 1586622770.611096, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622770.593961}
#
# #metrics {"Metrics": {"e3_term3.time": {"count": 1, "max": 20.097017288208008, "sum": 20.097017288208008, "min": 20.097017288208008}}, "EndTime": 1586622770.631909, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622770.611165}
#
# #metrics {"Metrics": {"whitened_m3_contribution_e3.time": {"count": 1, "max": 2708.936929702759, "sum": 2708.936929702759, "min": 2708.936929702759}}, "EndTime": 1586622770.64936, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622770.63197}
#
# #metrics {"Metrics": {"e2m1_term1.time": {"count": 1, "max": 1175.4910945892334, "sum": 1175.4910945892334, "min": 1175.4910945892334}, "from_numpy.time": {"count": 3, "max": 31.180858612060547, "sum": 35.71295738220215, "min": 1.4760494232177734}}, "EndTime": 1586622773.307562, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622770.649428}
#
# #metrics {"Metrics": {"e2m1_term2.time": {"count": 1, "max": 17.36617088317871, "sum": 17.36617088317871, "min": 17.36617088317871}}, "EndTime": 1586622773.325456, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622773.307669}
#
# #metrics {"Metrics": {"whitened_m3_contribution_e2_m1.time": {"count": 1, "max": 2695.0910091400146, "sum": 2695.0910091400146, "min": 2695.0910091400146}}, "EndTime": 1586622773.344549, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622773.325521}
#
# #metrics {"Metrics": {"whitened_m1_3.time": {"count": 1, "max": 0.1380443572998047, "sum": 0.1380443572998047, "min": 0.1380443572998047}}, "EndTime": 1586622773.344905, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622773.344607}
#
# #metrics {"Metrics": {"whitened_m3_contribution_m1_3.time": {"count": 1, "max": 0.39005279541015625, "sum": 0.39005279541015625, "min": 0.39005279541015625}}, "EndTime": 1586622773.345097, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622773.344961}
#
# #metrics {"Metrics": {"whitened_m3.time": {"count": 1, "max": 6078.31883430481, "sum": 6078.31883430481, "min": 6078.31883430481}}, "EndTime": 1586622773.347204, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622773.345148}
#
# #metrics {"Metrics": {"M3Whitening.time": {"count": 1, "max": 6078.485012054443, "sum": 6078.485012054443, "min": 6078.485012054443}}, "EndTime": 1586622773.347367, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622773.347247}
#
# [04/11/2020 16:32:53 INFO 139870123513664] Restart 1/10
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Using svd initialization.
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] iter=10, error=0.0823241025209, var=0.0
# [04/11/2020 16:32:53 INFO 139870123513664] Converged to local minimum in 10 iterations.
# [04/11/2020 16:32:53 INFO 139870123513664] Restart 2/10
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=0, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Using svd initialization.
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] iter=13, error=0.0823241025209, var=0.0
# [04/11/2020 16:32:53 INFO 139870123513664] Converged to local minimum in 13 iterations.
# [04/11/2020 16:32:53 INFO 139870123513664] Restart 3/10
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Using random initialization.
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] iter=10, error=0.0823241025209, var=0.0
# [04/11/2020 16:32:53 INFO 139870123513664] Converged to local minimum in 10 iterations.
# [04/11/2020 16:32:53 INFO 139870123513664] Restart 4/10
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Using random initialization.
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] iter=9, error=0.0823241025209, var=9.0503029071e-08
# [04/11/2020 16:32:53 INFO 139870123513664] Converged to local minimum in 9 iterations.
# [04/11/2020 16:32:53 INFO 139870123513664] Restart 5/10
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Using random initialization.
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] iter=9, error=0.0823241025209, var=9.0503029071e-08
# [04/11/2020 16:32:53 INFO 139870123513664] Converged to local minimum in 9 iterations.
# [04/11/2020 16:32:53 INFO 139870123513664] Restart 6/10
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Using random initialization.
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] iter=9, error=0.0823241025209, var=9.0503029071e-08
# [04/11/2020 16:32:53 INFO 139870123513664] Converged to local minimum in 9 iterations.
# [04/11/2020 16:32:53 INFO 139870123513664] Restart 7/10
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Using random initialization.
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] iter=9, error=0.0823241025209, var=9.0503029071e-08
# [04/11/2020 16:32:53 INFO 139870123513664] Converged to local minimum in 9 iterations.
# [04/11/2020 16:32:53 INFO 139870123513664] Restart 8/10
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:53 INFO 139870123513664] [CPDecomp] Using random initialization.
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] iter=9, error=0.0823241025209, var=0.0
# [04/11/2020 16:32:54 INFO 139870123513664] Converged to local minimum in 9 iterations.
# [04/11/2020 16:32:54 INFO 139870123513664] Restart 9/10
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] Using random initialization.
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] iter=9, error=0.0823241025209, var=9.0503029071e-08
# [04/11/2020 16:32:54 INFO 139870123513664] Converged to local minimum in 9 iterations.
# [04/11/2020 16:32:54 INFO 139870123513664] Restart 10/10
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] Starting CPDecomp...
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] Configuration: num_qr_iterations=5, line_search=True, relaxation_factor=scaled
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] Using random initialization.
# [04/11/2020 16:32:54 INFO 139870123513664] [CPDecomp] iter=10, error=0.0823241025209, var=0.0
# [04/11/2020 16:32:54 INFO 139870123513664] Converged to local minimum in 10 iterations.
# [04/11/2020 16:32:54 INFO 139870123513664] Best reconstruction error: 0.0823241
# #metrics {"Metrics": {"CPDecomposition.time": {"count": 1, "max": 826.2848854064941, "sum": 826.2848854064941, "min": 826.2848854064941}}, "EndTime": 1586622774.173743, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622773.347415}
#
# #metrics {"Metrics": {"LDA.update.time": {"count": 1, "max": 36568.44997406006, "sum": 36568.44997406006, "min": 36568.44997406006}, "to_numpy.time": {"count": 4, "max": 0.05412101745605469, "sum": 0.1380443572998047, "min": 0.025033950805664062}}, "EndTime": 1586622774.225805, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622774.173827}
#
# [04/11/2020 16:32:54 INFO 139870123513664] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 1009315, "sum": 1009315.0, "min": 1009315}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1009315, "sum": 1009315.0, "min": 1009315}, "Max Records Seen Between Resets": {"count": 1, "max": 1009315, "sum": 1009315.0, "min": 1009315}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586622774.226161, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "LDA", "epoch": 0}, "StartTime": 1586622774.226127}
#
# [04/11/2020 16:32:54 INFO 139870123513664] #throughput_metric: host=algo-1, train throughput=27600.3607573 records/second
# [04/11/2020 16:32:54 WARNING 139870123513664] wait_for_all_workers will not sync workers since the kv store is not running distributed
# #metrics {"Metrics": {"LDA.finalize.time": {"count": 1, "max": 0.024080276489257812, "sum": 0.024080276489257812, "min": 0.024080276489257812}}, "EndTime": 1586622774.226424, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622774.225898}
#
# [04/11/2020 16:32:54 INFO 139870123513664] Serializing LDA model to /opt/ml/model/model_algo-1
# #metrics {"Metrics": {"LDAModel.serialize.time": {"count": 1, "max": 0.9620189666748047, "sum": 0.9620189666748047, "min": 0.9620189666748047}}, "EndTime": 1586622774.227458, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622774.226467}
#
# [04/11/2020 16:32:54 INFO 139870123513664] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 40691.21789932251, "sum": 40691.21789932251, "min": 40691.21789932251}, "setuptime": {"count": 1, "max": 49.8199462890625, "sum": 49.8199462890625, "min": 49.8199462890625}}, "EndTime": 1586622774.253595, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "LDA"}, "StartTime": 1586622774.227502}
# 2020-04-11 16:33:03 Uploading - Uploading generated training model
# 2020-04-11 16:33:03 Completed - Training job completed
# Training seconds: 116
# Billable seconds: 116

# %% [markdown]
# # Endpoint Deployment and Prediction
#
# Below, we deploy the endpoint so that we can make predictions and generate the topic vectors for our data. We iterate through all million of our songs and generate 10 topic vectors for all of them.
#
# This part takes approximately 30 hours.

# %%
#deploy our endpoint for inference belo
lda_inference = lda.deploy(
    initial_instance_count=1,
    instance_type='ml.c4.xlarge',
)
lda_inference.content_type = 'text/csv'
lda_inference.serializer = csv_serializer
lda_inference.deserializer = json_deserializer
# Out:
# -------------!

# %%
empty = pd.DataFrame()
#Sagemaker only supports 10 predictions out of the endpoint at a time
#so we'll have to spoonfeed ten at a time and put the results in "empty"
inc = 10
for i in range(0,len(flat),inc): 
    
    #make the prediction
    if i+10 > len(flat):
        test = lda_inference.predict(np.array(x_tf[i:,:].todense()))
    else:
        test = lda_inference.predict(np.array(x_tf[i:i+inc,:].todense()))
    
    #turn it into a DF
    to_s3 = pd.DataFrame(pd.DataFrame.from_dict(test['predictions'])['topic_mixture'].values.tolist())
    
    #put the song IDs back on the predicted DF
    if i+inc > len(flat):
        to_s3 = pd.concat([to_s3,flat['song_id'].reset_index(drop=True)[i:].reset_index(drop=True)],axis = 1)

    else:
        to_s3 = pd.concat([to_s3,flat['song_id'].reset_index(drop=True)[i:i+inc].reset_index(drop=True)],axis = 1)
    
    #and append to empty
    empty = empty.append(to_s3)

    #a small progress report
    if i % 50000 == 0:
        print(i)

#this will eventually be uploaded to RDS, which can't accept dupes
##so enforce it at this point
empty.drop_duplicates('song_id', inplace = True)

#again, will be uploaded to RDS, which doesn't accept header or index
empty.to_csv('inference.csv', index=False, header=False)
csv_object = os.path.join(prefix, 'inference', 'inference.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(csv_object).upload_file('inference.csv')
# Out:
# 850000
# 900000
